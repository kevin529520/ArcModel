# %%
# 裁剪./p1-6_pictures/p2-1.bmp并保存图片
# 测试单张图片的裁剪

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
from PIL import Image, ImageDraw

img = Image.open('./raw_data_p1-7_pictures/capture0002.bmp')
# crop_left, crop_top, crop_right, crop_bottom =  413, 256, 943, 628   二次裁剪
# crop_left, crop_top, crop_right, crop_bottom = 546, 367, 1310, 914    #第一批图像
crop_left, crop_top, crop_right, crop_bottom = 547, 367, 1311, 914   #第二批图像
img = img.crop((crop_left, crop_top, crop_right, crop_bottom))

img = img.resize((820, 580))

img_array = np.asarray(img)
plt.imshow(img_array, cmap='gray')

# output_filename = os.path.join(output_path, 'cropped_p3.bmp')
img.save('./p1-6_pictures/crop0001_resize.bmp')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36840\2480307867.py in <module>
#      20
#      21 # output_filename = os.path.join(output_path, 'cropped_p3.bmp')
# ---> 22 img.save('./p1-6_pictures/crop0001_resize.bmp')
#
# c:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2315                 fp = builtins.open(filename, "r+b")
#    2316             else:
# -> 2317                 fp = builtins.open(filename, "w+b")
#    2318
#    2319         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './p1-6_pictures/crop0001_resize.bmp'

# %%
# 原始图像批量裁剪及二值化
# 提取工件截面

import numpy as np
from PIL import Image
import os
from PIL import Image, ImageDraw


# # 待处理的文件名前缀
# prefix = 't'
# # 待处理的文件夹路径
# folder_path = './jpg_picture/t=160/'
# 输出文件夹路径
for i in range(1,6):
        output_path = f'./cropped_binary_resized_mirror/cropped_binary_resized_mirror_p{i}/'
        folder_path = f'./raw_data_p1-7_pictures/p{i}_picture'

                # Create the output directory if it doesn't exist
        if not os.path.exists(output_path):
                os.makedirs(output_path)

        for filename in os.listdir(folder_path):
                # 裁剪的位置和大小
                crop_left, crop_top, crop_right, crop_bottom =  546, 367, 1310, 914

                # # 遍历文件夹中的所有bmp文件
                # for filename in os.listdir(folder_path):
                #     if filename.startswith(prefix) and filename.endswith('.jpg'):
                        # 打开图片
                img = Image.open(os.path.join(folder_path, filename))
                # img 一个图像对象，包含图像像素数据以及其他的属性的 

                # i=i+1
                # 裁剪
                img = img.crop((crop_left, crop_top, crop_right, crop_bottom))
#
                img = img.resize((820, 580))
                img = img.transpose(Image.FLIP_LEFT_RIGHT)

                # 二值化l
                img = img.convert('L')
                img_array = np.asarray(img)

                aa = img_array.copy()

                aa[img_array>240]=255
                aa[img_array<=240]=0

                        
                # 保存处理后的图片
                output_filename = os.path.join(output_path, f'./p{i}_'+filename.replace("capture", ""))
                # img.save(output_filename)
                xx = Image.fromarray(aa)
                xx.save(output_filename)
                        # import numpy as np

                        # print(type(img))
                        # print(img_array)
                        # import matplotlib.pyplot as plt
                        # plt.imshow(aa, cmap='gray')

# xx = Image.fromarray(aa)
# xx.save(output_filename)
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_36840\191812704.py:39: DeprecationWarning: FLIP_LEFT_RIGHT is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_LEFT_RIGHT instead.
#   img = img.transpose(Image.FLIP_LEFT_RIGHT)

# %%
# 原始图像批量裁剪及二值化
# 提取工件截面

import numpy as np
from PIL import Image
import os
from PIL import Image, ImageDraw


# # 待处理的文件名前缀
# prefix = 't'
# # 待处理的文件夹路径
# folder_path = './jpg_picture/t=160/'
# 输出文件夹路径
for i in range(6,8):
        output_path = f'./cropped_binary_resized_mirror/cropped_binary_resized_mirror_p{i}/'
        folder_path = f'./raw_data_p1-7_pictures/p{i}_picture'

                # Create the output directory if it doesn't exist
        if not os.path.exists(output_path):
                os.makedirs(output_path)

        for filename in os.listdir(folder_path):
                # 裁剪的位置和大小
                crop_left, crop_top, crop_right, crop_bottom =  547, 367, 1311, 914

                # # 遍历文件夹中的所有bmp文件
                # for filename in os.listdir(folder_path):
                #     if filename.startswith(prefix) and filename.endswith('.jpg'):
                        # 打开图片
                img = Image.open(os.path.join(folder_path, filename))
                # img 一个图像对象，包含图像像素数据以及其他的属性的 

                # i=i+1
                # 裁剪
                img = img.crop((crop_left, crop_top, crop_right, crop_bottom))
#
                img = img.resize((820, 580))
                img = img.transpose(Image.FLIP_LEFT_RIGHT)
                
                # 二值化l
                img = img.convert('L')
                img_array = np.asarray(img)

                aa = img_array.copy()

                aa[img_array>240]=255
                aa[img_array<=240]=0

                        
                # 保存处理后的图片
                output_filename = os.path.join(output_path, f'./p{i}_'+filename.replace("capture", ""))
                # img.save(output_filename)
                xx = Image.fromarray(aa)
                xx.save(output_filename)
                        # import numpy as np

                        # print(type(img))
                        # print(img_array)
                        # import matplotlib.pyplot as plt
                        # plt.imshow(aa, cmap='gray')

# xx = Image.fromarray(aa)
# xx.save(output_filename)
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_36840\2376731097.py:39: DeprecationWarning: FLIP_LEFT_RIGHT is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_LEFT_RIGHT instead.
#   img = img.transpose(Image.FLIP_LEFT_RIGHT)
