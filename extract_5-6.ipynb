# %%
import cv2
import os
from matplotlib import pyplot as plt
import numpy as np

# Define the paths to the cropped image folders
cropped_p5_folder = './cropped_binary_resized_mirror/cropped_binary_resized_mirror_p5/'
cropped_p6_folder = './cropped_binary_resized_mirror/cropped_binary_resized_mirror_p6/'

# Create a folder to save the extracted images
extracted_folder = './p2-7_extracted_cropped_binary/p6_extracted/'
if not os.path.exists(extracted_folder):
    os.makedirs(extracted_folder)

# Get the list of files in cropped_p6 folder
files_p6 = os.listdir(cropped_p6_folder)

# Iterate over the files in cropped_p6 folder
for file_p6 in files_p6:
    # Construct the paths for the corresponding images in cropped_p5 and cropped_p6 folders
    file_p5 = os.path.join(cropped_p5_folder, file_p6.replace('p6','p5'))
    file_p6 = os.path.join(cropped_p6_folder, file_p6)
    
    # Read the images
    img_p5 = cv2.imread(file_p5, cv2.IMREAD_GRAYSCALE)
    img_p6 = cv2.imread(file_p6, cv2.IMREAD_GRAYSCALE)
    

    # plt.imshow(img_p6, cmap='gray')
    # plt.axis('on')  # Turn off axis numbers
    # plt.show()
    # Subtract the images
    extracted_image = cv2.subtract(img_p5, img_p6)
    
# Invert the black and white colors
    # extracted_image = cv2.bitwise_not(extracted_image)

    # 黑色中找到白色的  （查找外轮廓）
    contours, _ = cv2.findContours(extracted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate over contours
    for contour in contours:
        area = cv2.contourArea(contour)
        if area < 1000:
            cv2.drawContours(extracted_image, [contour], -1, 0, thickness=cv2.FILLED)


    white_pixel_threshold = 5
    for col in range(extracted_image.shape[1]):
        white_pixel_count = np.sum(extracted_image[:, col] == 255)
        if white_pixel_count <= white_pixel_threshold:
            extracted_image[:, col] = 0  # Convert the column to black pixels

# Invert the black and white colors
    extracted_image = cv2.bitwise_not(extracted_image)

    black_pixel_count = np.sum(extracted_image == 0)
    print("Number of black pixels: ", black_pixel_count)
    # Calculate the area of black pixels in square millimeters
    black_area_mm = black_pixel_count * (29/550)**2
    print("Area of black pixels in square millimeters: ", black_area_mm)


    plt.imshow(extracted_image, cmap='gray')
    plt.axis('on')  # Turn off axis numbers
    plt.show()
    # Save the extracted image
    file_p6 = file_p6.replace('p6_','')
    cv2.imwrite(os.path.join(extracted_folder, 'p6_extracted_' + file_p6.split("/")[-1]), extracted_image)
# Out:
# Number of black pixels:  19182
# Area of black pixels in square millimeters:  53.32913057851239
# Number of black pixels:  19275
# Area of black pixels in square millimeters:  53.587685950413224
# Number of black pixels:  19239
# Area of black pixels in square millimeters:  53.4876
# Number of black pixels:  19129
# Area of black pixels in square millimeters:  53.18178181818182
# Number of black pixels:  18988
# Area of black pixels in square millimeters:  52.789778512396694
# Number of black pixels:  18701
# Area of black pixels in square millimeters:  51.991871074380164
# Number of black pixels:  18533
# Area of black pixels in square millimeters:  51.52480330578512
# Number of black pixels:  18398
# Area of black pixels in square millimeters:  51.14948099173554
# Number of black pixels:  18338
# Area of black pixels in square millimeters:  50.982671074380164
# Number of black pixels:  18347
# Area of black pixels in square millimeters:  51.00769256198347
# Number of black pixels:  18458
# Area of black pixels in square millimeters:  51.31629090909091
# Number of black pixels:  18611
# Area of black pixels in square millimeters:  51.74165619834711
# Number of black pixels:  18729
# Area of black pixels in square millimeters:  52.069715702479336
# Number of black pixels:  18849
# Area of black pixels in square millimeters:  52.40333553719008
# Number of black pixels:  18999
# Area of black pixels in square millimeters:  52.82036033057851
# Number of black pixels:  19237
# Area of black pixels in square millimeters:  53.48203966942148
# Number of black pixels:  19517
# Area of black pixels in square millimeters:  54.26048595041322
# Number of black pixels:  19795
# Area of black pixels in square millimeters:  55.033371900826445
# Number of black pixels:  19986
# Area of black pixels in square millimeters:  55.56438347107438
# Number of black pixels:  20151
# Area of black pixels in square millimeters:  56.02311074380165
# Number of black pixels:  20457
# Area of black pixels in square millimeters:  56.87384132231405
# Number of black pixels:  20634
# Area of black pixels in square millimeters:  57.3659305785124
# Number of black pixels:  20683
# Area of black pixels in square millimeters:  57.50215867768595
# Number of black pixels:  20778
# Area of black pixels in square millimeters:  57.766274380165285
# Number of black pixels:  20795
# Area of black pixels in square millimeters:  57.81353719008264
# Number of black pixels:  20576
# Area of black pixels in square millimeters:  57.204680991735536
# Number of black pixels:  20340
# Area of black pixels in square millimeters:  56.548561983471075
# Number of black pixels:  20138
# Area of black pixels in square millimeters:  55.98696859504132
# Number of black pixels:  19819
# Area of black pixels in square millimeters:  55.100095867768594
# Number of black pixels:  19536
# Area of black pixels in square millimeters:  54.31330909090909
# Number of black pixels:  19092
# Area of black pixels in square millimeters:  53.078915702479335
# Number of black pixels:  18564
# Area of black pixels in square millimeters:  51.61098842975206
# Number of black pixels:  18049
# Area of black pixels in square millimeters:  50.17920330578512
# Number of black pixels:  17584
# Area of black pixels in square millimeters:  48.88642644628099
# Number of black pixels:  17133
# Area of black pixels in square millimeters:  47.63257190082644
# Number of black pixels:  16595
# Area of black pixels in square millimeters:  46.13684297520661
# Number of black pixels:  15820
# Area of black pixels in square millimeters:  43.982214876033055
# Number of black pixels:  15036
# Area of black pixels in square millimeters:  41.802565289256194
# Number of black pixels:  14068
# Area of black pixels in square millimeters:  39.1113652892562
# Number of black pixels:  13198
# Area of black pixels in square millimeters:  36.692621487603304
# Number of black pixels:  12333
# Area of black pixels in square millimeters:  34.28777851239669
# Number of black pixels:  11581
# Area of black pixels in square millimeters:  32.19709421487603
# Number of black pixels:  10538
# Area of black pixels in square millimeters:  29.297381818181815
# Number of black pixels:  9166
# Area of black pixels in square millimeters:  25.48299504132231
# Number of black pixels:  7568
# Area of black pixels in square millimeters:  21.04029090909091
# Number of black pixels:  6587
# Area of black pixels in square millimeters:  18.312948760330578
# Number of black pixels:  5865
# Area of black pixels in square millimeters:  16.305669421487604
# Number of black pixels:  5403
# Area of black pixels in square millimeters:  15.021233057851239
# Number of black pixels:  4930
# Area of black pixels in square millimeters:  13.706214876033057
# Number of black pixels:  4433
# Area of black pixels in square millimeters:  12.324472727272727
# Number of black pixels:  3993
# Area of black pixels in square millimeters:  11.1012
# Number of black pixels:  3706
# Area of black pixels in square millimeters:  10.30329256198347
# Number of black pixels:  3529
# Area of black pixels in square millimeters:  9.811203305785124
# Number of black pixels:  3439
# Area of black pixels in square millimeters:  9.560988429752065
# Number of black pixels:  3528
# Area of black pixels in square millimeters:  9.808423140495867
# Number of black pixels:  3688
# Area of black pixels in square millimeters:  10.253249586776858
# Number of black pixels:  4178
# Area of black pixels in square millimeters:  11.615530578512397
# Number of black pixels:  4973
# Area of black pixels in square millimeters:  13.825761983471073
# Number of black pixels:  5928
# Area of black pixels in square millimeters:  16.480819834710744
# Number of black pixels:  6672
# Area of black pixels in square millimeters:  18.549262809917355
# Number of black pixels:  7357
# Area of black pixels in square millimeters:  20.45367603305785
# Number of black pixels:  8113
# Area of black pixels in square millimeters:  22.555480991735536
# Number of black pixels:  8684
# Area of black pixels in square millimeters:  24.142955371900825
# Number of black pixels:  9277
# Area of black pixels in square millimeters:  25.79159338842975
# Number of black pixels:  9949
# Area of black pixels in square millimeters:  27.659864462809917
# Number of black pixels:  10558
# Area of black pixels in square millimeters:  29.352985123966942
# Number of black pixels:  11093
# Area of black pixels in square millimeters:  30.840373553719008
# Number of black pixels:  11528
# Area of black pixels in square millimeters:  32.04974545454545
# Number of black pixels:  11860
# Area of black pixels in square millimeters:  32.97276033057851
# Number of black pixels:  12147
# Area of black pixels in square millimeters:  33.77066776859504
# Number of black pixels:  12454
# Area of black pixels in square millimeters:  34.62417851239669
# Number of black pixels:  12730
# Area of black pixels in square millimeters:  35.391504132231404
# Number of black pixels:  12982
# Area of black pixels in square millimeters:  36.09210578512396
# Number of black pixels:  13195
# Area of black pixels in square millimeters:  36.684280991735534
# Number of black pixels:  13384
# Area of black pixels in square millimeters:  37.209732231404956
# Number of black pixels:  13598
# Area of black pixels in square millimeters:  37.80468760330579
# Number of black pixels:  13770
# Area of black pixels in square millimeters:  38.282876033057846
# Number of black pixels:  14017
# Area of black pixels in square millimeters:  38.96957685950413
# Number of black pixels:  14250
# Area of black pixels in square millimeters:  39.61735537190083
# Number of black pixels:  14661
# Area of black pixels in square millimeters:  40.76000330578512
# Number of black pixels:  14961
# Area of black pixels in square millimeters:  41.59405289256198
# Number of black pixels:  15308
# Area of black pixels in square millimeters:  42.558770247933886
# Number of black pixels:  15479
# Area of black pixels in square millimeters:  43.03417851239669
# Number of black pixels:  15724
# Area of black pixels in square millimeters:  43.71531900826446
# Number of black pixels:  15988
# Area of black pixels in square millimeters:  44.4492826446281
# Number of black pixels:  16224
# Area of black pixels in square millimeters:  45.10540165289256
# Number of black pixels:  16396
# Area of black pixels in square millimeters:  45.583590082644626
# Number of black pixels:  16598
# Area of black pixels in square millimeters:  46.145183471074375
# Number of black pixels:  16709
# Area of black pixels in square millimeters:  46.45378181818182
# Number of black pixels:  16730
# Area of black pixels in square millimeters:  46.512165289256195
# Number of black pixels:  16674
# Area of black pixels in square millimeters:  46.35647603305785
# Number of black pixels:  16660
# Area of black pixels in square millimeters:  46.31755371900826
# Number of black pixels:  16690
# Area of black pixels in square millimeters:  46.40095867768595
# Number of black pixels:  16786
# Area of black pixels in square millimeters:  46.667854545454546
# Number of black pixels:  16884
# Area of black pixels in square millimeters:  46.94031074380165
# Number of black pixels:  17033
# Area of black pixels in square millimeters:  47.35455537190082
# Number of black pixels:  17106
# Area of black pixels in square millimeters:  47.55750743801653
# Number of black pixels:  17265
# Area of black pixels in square millimeters:  47.99955371900826
# Number of black pixels:  17404
# Area of black pixels in square millimeters:  48.385996694214874
# Number of black pixels:  17531
# Area of black pixels in square millimeters:  48.73907768595041
# Number of black pixels:  17588
# Area of black pixels in square millimeters:  48.897547107438015
# Number of black pixels:  17746
# Area of black pixels in square millimeters:  49.336813223140496
# Number of black pixels:  17832
# Area of black pixels in square millimeters:  49.57590743801653
# Number of black pixels:  17925
# Area of black pixels in square millimeters:  49.834462809917355
# Number of black pixels:  18053
# Area of black pixels in square millimeters:  50.190323966942145
# Number of black pixels:  18051
# Area of black pixels in square millimeters:  50.184763636363634
# Number of black pixels:  18166
# Area of black pixels in square millimeters:  50.5044826446281
# Number of black pixels:  18184
# Area of black pixels in square millimeters:  50.554525619834706
# Number of black pixels:  18189
# Area of black pixels in square millimeters:  50.56842644628099
# Number of black pixels:  18142
# Area of black pixels in square millimeters:  50.43775867768595
# Number of black pixels:  18291
# Area of black pixels in square millimeters:  50.852003305785125
# Number of black pixels:  18397
# Area of black pixels in square millimeters:  51.14670082644628
# Number of black pixels:  18404
# Area of black pixels in square millimeters:  51.16616198347107
# Number of black pixels:  18412
# Area of black pixels in square millimeters:  51.18840330578512
# Number of black pixels:  18500
# Area of black pixels in square millimeters:  51.43305785123967
# Number of black pixels:  18530
# Area of black pixels in square millimeters:  51.51646280991735
# Number of black pixels:  18436
# Area of black pixels in square millimeters:  51.25512727272727
# Number of black pixels:  18378
# Area of black pixels in square millimeters:  51.09387768595041
# Number of black pixels:  18469
# Area of black pixels in square millimeters:  51.346872727272725
# Number of black pixels:  18597
# Area of black pixels in square millimeters:  51.702733884297515
# Number of black pixels:  18622
# Area of black pixels in square millimeters:  51.772238016528924
# Number of black pixels:  18502
# Area of black pixels in square millimeters:  51.43861818181818
# Number of black pixels:  18411
# Area of black pixels in square millimeters:  51.18562314049586
# Number of black pixels:  18300
# Area of black pixels in square millimeters:  50.87702479338843
# Number of black pixels:  18134
# Area of black pixels in square millimeters:  50.4155173553719
# Number of black pixels:  18050
# Area of black pixels in square millimeters:  50.181983471074375
# Number of black pixels:  17958
# Area of black pixels in square millimeters:  49.92620826446281
# Number of black pixels:  17952
# Area of black pixels in square millimeters:  49.90952727272727
# Number of black pixels:  17935
# Area of black pixels in square millimeters:  49.86226446280992
# Number of black pixels:  17828
# Area of black pixels in square millimeters:  49.5647867768595
# Number of black pixels:  17692
# Area of black pixels in square millimeters:  49.18668429752066
# Number of black pixels:  17729
# Area of black pixels in square millimeters:  49.28955041322314
# Number of black pixels:  17750
# Area of black pixels in square millimeters:  49.34793388429752
# Number of black pixels:  17505
# Area of black pixels in square millimeters:  48.66679338842975
# Number of black pixels:  17335
# Area of black pixels in square millimeters:  48.1941652892562
# Number of black pixels:  17095
# Area of black pixels in square millimeters:  47.52692561983471
# Number of black pixels:  16763
# Area of black pixels in square millimeters:  46.60391074380165
# Number of black pixels:  16538
# Area of black pixels in square millimeters:  45.97837355371901
# Number of black pixels:  16273
# Area of black pixels in square millimeters:  45.24162975206611
# Number of black pixels:  16008
# Area of black pixels in square millimeters:  44.50488595041322
# Number of black pixels:  15792
# Area of black pixels in square millimeters:  43.90437024793388
# Number of black pixels:  15549
# Area of black pixels in square millimeters:  43.22879008264463
# Number of black pixels:  15306
# Area of black pixels in square millimeters:  42.55320991735537
# Number of black pixels:  15194
# Area of black pixels in square millimeters:  42.241831404958674
# Number of black pixels:  15082
# Area of black pixels in square millimeters:  41.93045289256198
# Number of black pixels:  15016
# Area of black pixels in square millimeters:  41.746961983471074
# Number of black pixels:  14939
# Area of black pixels in square millimeters:  41.532889256198345
# Number of black pixels:  15032
# Area of black pixels in square millimeters:  41.79144462809917
# Number of black pixels:  15157
# Area of black pixels in square millimeters:  42.1389652892562
# Number of black pixels:  15257
# Area of black pixels in square millimeters:  42.41698181818182
# Number of black pixels:  15346
# Area of black pixels in square millimeters:  42.66441652892562
# Number of black pixels:  15514
# Area of black pixels in square millimeters:  43.13148429752066
# Number of black pixels:  15668
# Area of black pixels in square millimeters:  43.559629752066115
# Number of black pixels:  15812
# Area of black pixels in square millimeters:  43.959973553719
# Number of black pixels:  16124
# Area of black pixels in square millimeters:  44.82738512396694
# Number of black pixels:  16456
# Area of black pixels in square millimeters:  45.7504
# Number of black pixels:  16520
# Area of black pixels in square millimeters:  45.928330578512394
# Number of black pixels:  16577
# Area of black pixels in square millimeters:  46.0868
# Number of black pixels:  16640
# Area of black pixels in square millimeters:  46.26195041322314
# Number of black pixels:  16718
# Area of black pixels in square millimeters:  46.47880330578512
# Number of black pixels:  16655
# Area of black pixels in square millimeters:  46.303652892561985
# Number of black pixels:  16739
# Area of black pixels in square millimeters:  46.5371867768595
# Number of black pixels:  16783
# Area of black pixels in square millimeters:  46.659514049586775
# Number of black pixels:  16785
# Area of black pixels in square millimeters:  46.66507438016529
# Number of black pixels:  16835
# Area of black pixels in square millimeters:  46.804082644628096
# Number of black pixels:  16829
# Area of black pixels in square millimeters:  46.78740165289256
# Number of black pixels:  16777
# Area of black pixels in square millimeters:  46.642833057851234
# Number of black pixels:  16673
# Area of black pixels in square millimeters:  46.35369586776859
# Number of black pixels:  16628
# Area of black pixels in square millimeters:  46.228588429752065
# Number of black pixels:  16617
# Area of black pixels in square millimeters:  46.19800661157024
# Number of black pixels:  16630
# Area of black pixels in square millimeters:  46.23414876033058
# Number of black pixels:  16642
# Area of black pixels in square millimeters:  46.26751074380165
# Number of black pixels:  16590
# Area of black pixels in square millimeters:  46.12294214876033
# Number of black pixels:  16614
# Area of black pixels in square millimeters:  46.18966611570248
# Number of black pixels:  16625
# Area of black pixels in square millimeters:  46.220247933884295
# Number of black pixels:  16502
# Area of black pixels in square millimeters:  45.878287603305786
# Number of black pixels:  16331
# Area of black pixels in square millimeters:  45.40287933884297
# Number of black pixels:  16118
# Area of black pixels in square millimeters:  44.8107041322314
# Number of black pixels:  15870
# Area of black pixels in square millimeters:  44.121223140495864
# Number of black pixels:  15683
# Area of black pixels in square millimeters:  43.60133223140496
# Number of black pixels:  15399
# Area of black pixels in square millimeters:  42.81176528925619
# Number of black pixels:  14952
# Area of black pixels in square millimeters:  41.56903140495868
# Number of black pixels:  14441
# Area of black pixels in square millimeters:  40.14836694214876
# Number of black pixels:  13996
# Area of black pixels in square millimeters:  38.91119338842975
# Number of black pixels:  13336
# Area of black pixels in square millimeters:  37.07628429752066
# Number of black pixels:  12728
# Area of black pixels in square millimeters:  35.38594380165289
# Number of black pixels:  12011
# Area of black pixels in square millimeters:  33.3925652892562
# Number of black pixels:  11268
# Area of black pixels in square millimeters:  31.32690247933884
# Number of black pixels:  10614
# Area of black pixels in square millimeters:  29.50867438016529
# Number of black pixels:  9926
# Area of black pixels in square millimeters:  27.595920661157024
# Number of black pixels:  9193
# Area of black pixels in square millimeters:  25.55805950413223
# Number of black pixels:  7659
# Area of black pixels in square millimeters:  21.29328595041322
# Number of black pixels:  6628
# Area of black pixels in square millimeters:  18.426935537190083
# Number of black pixels:  5903
# Area of black pixels in square millimeters:  16.41131570247934
# Number of black pixels:  5417
# Area of black pixels in square millimeters:  15.060155371900827
# Number of black pixels:  5059
# Area of black pixels in square millimeters:  14.064856198347107
# Number of black pixels:  4904
# Area of black pixels in square millimeters:  13.633930578512397
# Number of black pixels:  4820
# Area of black pixels in square millimeters:  13.400396694214875
# Number of black pixels:  5012
# Area of black pixels in square millimeters:  13.934188429752066
# Number of black pixels:  5127
# Area of black pixels in square millimeters:  14.253907438016528
# Number of black pixels:  5376
# Area of black pixels in square millimeters:  14.946168595041321
# Number of black pixels:  6136
# Area of black pixels in square millimeters:  17.059094214876033
# Number of black pixels:  6631
# Area of black pixels in square millimeters:  18.43527603305785
# Number of black pixels:  7168
# Area of black pixels in square millimeters:  19.92822479338843
# Number of black pixels:  7857
# Area of black pixels in square millimeters:  21.84375867768595
# Number of black pixels:  8476
# Area of black pixels in square millimeters:  23.564680991735536
# Number of black pixels:  9129
# Area of black pixels in square millimeters:  25.380128925619832
# Number of black pixels:  9631
# Area of black pixels in square millimeters:  26.775771900826445
# Number of black pixels:  10068
# Area of black pixels in square millimeters:  27.990704132231404
# Number of black pixels:  10608
# Area of black pixels in square millimeters:  29.49199338842975
# Number of black pixels:  10979
# Area of black pixels in square millimeters:  30.5234347107438
# Number of black pixels:  11273
# Area of black pixels in square millimeters:  31.340803305785123
# Number of black pixels:  11542
# Area of black pixels in square millimeters:  32.08866776859504
# Number of black pixels:  11627
# Area of black pixels in square millimeters:  32.32498181818182
# Number of black pixels:  11330
# Area of black pixels in square millimeters:  31.499272727272725
# Number of black pixels:  11320
# Area of black pixels in square millimeters:  31.471471074380165
# Number of black pixels:  11211
# Area of black pixels in square millimeters:  31.16843305785124
# Number of black pixels:  11213
# Area of black pixels in square millimeters:  31.17399338842975
# Number of black pixels:  11353
# Area of black pixels in square millimeters:  31.56321652892562
# Number of black pixels:  11446
# Area of black pixels in square millimeters:  31.821771900826445
# Number of black pixels:  11401
# Area of black pixels in square millimeters:  31.696664462809917
# Number of black pixels:  11428
# Area of black pixels in square millimeters:  31.771728925619833
# Number of black pixels:  11099
# Area of black pixels in square millimeters:  30.857054545454545
# Number of black pixels:  10696
# Area of black pixels in square millimeters:  29.736647933884296
# Number of black pixels:  10446
# Area of black pixels in square millimeters:  29.041606611570245
# Number of black pixels:  9962
# Area of black pixels in square millimeters:  27.696006611570247
# Number of black pixels:  9678
# Area of black pixels in square millimeters:  26.906439669421488
# Number of black pixels:  9564
# Area of black pixels in square millimeters:  26.58950082644628
# Number of black pixels:  9544
# Area of black pixels in square millimeters:  26.533897520661156
# Number of black pixels:  9506
# Area of black pixels in square millimeters:  26.42825123966942
# Number of black pixels:  9567
# Area of black pixels in square millimeters:  26.59784132231405
# Number of black pixels:  9798
# Area of black pixels in square millimeters:  27.24005950413223
# Number of black pixels:  10149
# Area of black pixels in square millimeters:  28.215897520661155
# Number of black pixels:  10565
# Area of black pixels in square millimeters:  29.372446280991735
# Number of black pixels:  10927
# Area of black pixels in square millimeters:  30.37886611570248
# Number of black pixels:  11283
# Area of black pixels in square millimeters:  31.368604958677686
# Number of black pixels:  11533
# Area of black pixels in square millimeters:  32.06364628099173
# Number of black pixels:  12296
# Area of black pixels in square millimeters:  34.184912396694216
# Number of black pixels:  13298
# Area of black pixels in square millimeters:  36.97063801652892
# Number of black pixels:  14254
# Area of black pixels in square millimeters:  39.62847603305785
# Number of black pixels:  15025
# Area of black pixels in square millimeters:  41.77198347107438
# Number of black pixels:  15805
# Area of black pixels in square millimeters:  43.94051239669421
# Number of black pixels:  16430
# Area of black pixels in square millimeters:  45.67811570247934
# Number of black pixels:  17088
# Area of black pixels in square millimeters:  47.507464462809914
# Number of black pixels:  17718
# Area of black pixels in square millimeters:  49.25896859504132
# Number of black pixels:  18318
# Area of black pixels in square millimeters:  50.92706776859504
# Number of black pixels:  19542
# Area of black pixels in square millimeters:  54.32999008264463
# Number of black pixels:  19929
# Area of black pixels in square millimeters:  55.40591404958678
# Number of black pixels:  20574
# Area of black pixels in square millimeters:  57.199120661157025
# Number of black pixels:  21176
# Area of black pixels in square millimeters:  58.87278016528926
# Number of black pixels:  21654
# Area of black pixels in square millimeters:  60.20169917355371
# Number of black pixels:  22115
# Area of black pixels in square millimeters:  61.48335537190082
# Number of black pixels:  22410
# Area of black pixels in square millimeters:  62.3035041322314
# Number of black pixels:  22121
# Area of black pixels in square millimeters:  61.50003636363636
# Number of black pixels:  21678
# Area of black pixels in square millimeters:  60.26842314049586
# Number of black pixels:  21761
# Area of black pixels in square millimeters:  60.49917685950413
# Number of black pixels:  20433
# Area of black pixels in square millimeters:  56.8071173553719
# Number of black pixels:  19457
# Area of black pixels in square millimeters:  54.09367603305785
