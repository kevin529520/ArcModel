# %%
import cv2
import os
from matplotlib import pyplot as plt
import numpy as np

# Define the paths to the cropped image folders
cropped_p4_folder = './cropped_binary_resized_mirror/cropped_binary_resized_mirror_p4/'
cropped_p5_folder = './cropped_binary_resized_mirror/cropped_binary_resized_mirror_p5/'

# Create a folder to save the extracted images
extracted_folder = './p2-7_extracted_cropped_binary/p5_extracted/'
if not os.path.exists(extracted_folder):
    os.makedirs(extracted_folder)

# Get the list of files in cropped_p5 folder
files_p5 = os.listdir(cropped_p5_folder)

# Iterate over the files in cropped_p5 folder
for file_p5 in files_p5:
    # Construct the paths for the corresponding images in cropped_p4 and cropped_p5 folders
    file_p4 = os.path.join(cropped_p4_folder, file_p5.replace('p5','p4'))
    file_p5 = os.path.join(cropped_p5_folder, file_p5)
    
    # Read the images
    img_p4 = cv2.imread(file_p4, cv2.IMREAD_GRAYSCALE)
    img_p5 = cv2.imread(file_p5, cv2.IMREAD_GRAYSCALE)
    

    # plt.imshow(img_p5, cmap='gray')
    # plt.axis('on')  # Turn off axis numbers
    # plt.show()
    # Subtract the images
    extracted_image = cv2.subtract(img_p4, img_p5)
    
# Invert the black and white colors
    # extracted_image = cv2.bitwise_not(extracted_image)

    # 黑色中找到白色的  （查找外轮廓）
    contours, _ = cv2.findContours(extracted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate over contours
    for contour in contours:
        area = cv2.contourArea(contour)
        if area < 1000:
            cv2.drawContours(extracted_image, [contour], -1, 0, thickness=cv2.FILLED)


    white_pixel_threshold = 5
    for col in range(extracted_image.shape[1]):
        white_pixel_count = np.sum(extracted_image[:, col] == 255)
        if white_pixel_count <= white_pixel_threshold:
            extracted_image[:, col] = 0  # Convert the column to black pixels

# Invert the black and white colors
    extracted_image = cv2.bitwise_not(extracted_image)

    black_pixel_count = np.sum(extracted_image == 0)
    print("Number of black pixels: ", black_pixel_count)
    # Calculate the area of black pixels in square millimeters
    black_area_mm = black_pixel_count * (29/550)**2
    print("Area of black pixels in square millimeters: ", black_area_mm)


    plt.imshow(extracted_image, cmap='gray')
    plt.axis('on')  # Turn off axis numbers
    plt.show()
    # Save the extracted image
    file_p5 = file_p5.replace('p5_','')
    cv2.imwrite(os.path.join(extracted_folder, 'p5_extracted_' + file_p5.split("/")[-1]), extracted_image)
# Out:
# Number of black pixels:  22540
# Area of black pixels in square millimeters:  62.664925619834705
# Number of black pixels:  22490
# Area of black pixels in square millimeters:  62.525917355371895
# Number of black pixels:  22313
# Area of black pixels in square millimeters:  62.033828099173554
# Number of black pixels:  22139
# Area of black pixels in square millimeters:  61.55007933884297
# Number of black pixels:  21856
# Area of black pixels in square millimeters:  60.76329256198347
# Number of black pixels:  21684
# Area of black pixels in square millimeters:  60.2851041322314
# Number of black pixels:  21553
# Area of black pixels in square millimeters:  59.92090247933884
# Number of black pixels:  21434
# Area of black pixels in square millimeters:  59.590062809917356
# Number of black pixels:  21224
# Area of black pixels in square millimeters:  59.00622809917355
# Number of black pixels:  21153
# Area of black pixels in square millimeters:  58.80883636363636
# Number of black pixels:  20973
# Area of black pixels in square millimeters:  58.30840661157025
# Number of black pixels:  20805
# Area of black pixels in square millimeters:  57.841338842975205
# Number of black pixels:  20607
# Area of black pixels in square millimeters:  57.29086611570248
# Number of black pixels:  20363
# Area of black pixels in square millimeters:  56.612505785123965
# Number of black pixels:  20062
# Area of black pixels in square millimeters:  55.77567603305785
# Number of black pixels:  19790
# Area of black pixels in square millimeters:  55.019471074380164
# Number of black pixels:  19438
# Area of black pixels in square millimeters:  54.04085289256198
# Number of black pixels:  19185
# Area of black pixels in square millimeters:  53.33747107438016
# Number of black pixels:  18963
# Area of black pixels in square millimeters:  52.720274380165286
# Number of black pixels:  18755
# Area of black pixels in square millimeters:  52.141999999999996
# Number of black pixels:  18525
# Area of black pixels in square millimeters:  51.502561983471075
# Number of black pixels:  18214
# Area of black pixels in square millimeters:  50.637930578512396
# Number of black pixels:  17932
# Area of black pixels in square millimeters:  49.85392396694215
# Number of black pixels:  17680
# Area of black pixels in square millimeters:  49.15332231404958
# Number of black pixels:  17452
# Area of black pixels in square millimeters:  48.51944462809917
# Number of black pixels:  17168
# Area of black pixels in square millimeters:  47.72987768595041
# Number of black pixels:  17018
# Area of black pixels in square millimeters:  47.312852892561985
# Number of black pixels:  16917
# Area of black pixels in square millimeters:  47.03205619834711
# Number of black pixels:  16870
# Area of black pixels in square millimeters:  46.90138842975207
# Number of black pixels:  16842
# Area of black pixels in square millimeters:  46.82354380165289
# Number of black pixels:  16763
# Area of black pixels in square millimeters:  46.60391074380165
# Number of black pixels:  16736
# Area of black pixels in square millimeters:  46.528846280991736
# Number of black pixels:  16514
# Area of black pixels in square millimeters:  45.91164958677686
# Number of black pixels:  16490
# Area of black pixels in square millimeters:  45.84492561983471
# Number of black pixels:  16406
# Area of black pixels in square millimeters:  45.61139173553719
# Number of black pixels:  16332
# Area of black pixels in square millimeters:  45.40565950413223
# Number of black pixels:  16399
# Area of black pixels in square millimeters:  45.5919305785124
# Number of black pixels:  16361
# Area of black pixels in square millimeters:  45.48628429752066
# Number of black pixels:  16428
# Area of black pixels in square millimeters:  45.67255537190083
# Number of black pixels:  16227
# Area of black pixels in square millimeters:  45.11374214876033
# Number of black pixels:  15792
# Area of black pixels in square millimeters:  43.90437024793388
# Number of black pixels:  15818
# Area of black pixels in square millimeters:  43.976654545454544
# Number of black pixels:  16144
# Area of black pixels in square millimeters:  44.88298842975206
# Number of black pixels:  16638
# Area of black pixels in square millimeters:  46.25639008264463
# Number of black pixels:  17271
# Area of black pixels in square millimeters:  48.0162347107438
# Number of black pixels:  17575
# Area of black pixels in square millimeters:  48.86140495867768
# Number of black pixels:  17818
# Area of black pixels in square millimeters:  49.53698512396694
# Number of black pixels:  18092
# Area of black pixels in square millimeters:  50.29875041322314
# Number of black pixels:  18231
# Area of black pixels in square millimeters:  50.68519338842975
# Number of black pixels:  18522
# Area of black pixels in square millimeters:  51.494221487603305
# Number of black pixels:  18841
# Area of black pixels in square millimeters:  52.38109421487603
# Number of black pixels:  19074
# Area of black pixels in square millimeters:  53.02887272727273
# Number of black pixels:  19294
# Area of black pixels in square millimeters:  53.64050909090909
# Number of black pixels:  19469
# Area of black pixels in square millimeters:  54.12703801652892
# Number of black pixels:  19587
# Area of black pixels in square millimeters:  54.455097520661155
# Number of black pixels:  19643
# Area of black pixels in square millimeters:  54.6107867768595
# Number of black pixels:  19639
# Area of black pixels in square millimeters:  54.599666115702476
# Number of black pixels:  19630
# Area of black pixels in square millimeters:  54.57464462809917
# Number of black pixels:  19695
# Area of black pixels in square millimeters:  54.755355371900826
# Number of black pixels:  19465
# Area of black pixels in square millimeters:  54.1159173553719
# Number of black pixels:  19270
# Area of black pixels in square millimeters:  53.57378512396694
# Number of black pixels:  18823
# Area of black pixels in square millimeters:  52.33105123966942
# Number of black pixels:  18440
# Area of black pixels in square millimeters:  51.266247933884294
# Number of black pixels:  17982
# Area of black pixels in square millimeters:  49.99293223140496
# Number of black pixels:  17487
# Area of black pixels in square millimeters:  48.61675041322314
# Number of black pixels:  16913
# Area of black pixels in square millimeters:  47.020935537190084
# Number of black pixels:  16725
# Area of black pixels in square millimeters:  46.498264462809914
# Number of black pixels:  16433
# Area of black pixels in square millimeters:  45.6864561983471
# Number of black pixels:  16193
# Area of black pixels in square millimeters:  45.01921652892562
# Number of black pixels:  16355
# Area of black pixels in square millimeters:  45.46960330578512
# Number of black pixels:  16204
# Area of black pixels in square millimeters:  45.04979834710743
# Number of black pixels:  16195
# Area of black pixels in square millimeters:  45.02477685950413
# Number of black pixels:  16020
# Area of black pixels in square millimeters:  44.53824793388429
# Number of black pixels:  15987
# Area of black pixels in square millimeters:  44.44650247933884
# Number of black pixels:  15911
# Area of black pixels in square millimeters:  44.23520991735537
# Number of black pixels:  15866
# Area of black pixels in square millimeters:  44.11010247933884
# Number of black pixels:  15731
# Area of black pixels in square millimeters:  43.73478016528925
# Number of black pixels:  15577
# Area of black pixels in square millimeters:  43.3066347107438
# Number of black pixels:  15510
# Area of black pixels in square millimeters:  43.120363636363635
# Number of black pixels:  15394
# Area of black pixels in square millimeters:  42.79786446280992
# Number of black pixels:  15274
# Area of black pixels in square millimeters:  42.46424462809917
# Number of black pixels:  15130
# Area of black pixels in square millimeters:  42.06390082644628
# Number of black pixels:  15010
# Area of black pixels in square millimeters:  41.73028099173553
# Number of black pixels:  14641
# Area of black pixels in square millimeters:  40.7044
# Number of black pixels:  14415
# Area of black pixels in square millimeters:  40.076082644628094
# Number of black pixels:  14141
# Area of black pixels in square millimeters:  39.3143173553719
# Number of black pixels:  13913
# Area of black pixels in square millimeters:  38.68043966942149
# Number of black pixels:  13768
# Area of black pixels in square millimeters:  38.277315702479335
# Number of black pixels:  13544
# Area of black pixels in square millimeters:  37.65455867768595
# Number of black pixels:  13379
# Area of black pixels in square millimeters:  37.195831404958675
# Number of black pixels:  13267
# Area of black pixels in square millimeters:  36.88445289256198
# Number of black pixels:  13224
# Area of black pixels in square millimeters:  36.764905785123965
# Number of black pixels:  13265
# Area of black pixels in square millimeters:  36.87889256198347
# Number of black pixels:  13217
# Area of black pixels in square millimeters:  36.74544462809917
# Number of black pixels:  13150
# Area of black pixels in square millimeters:  36.559173553719006
# Number of black pixels:  13012
# Area of black pixels in square millimeters:  36.17551074380165
# Number of black pixels:  12932
# Area of black pixels in square millimeters:  35.95309752066115
# Number of black pixels:  12776
# Area of black pixels in square millimeters:  35.51939173553719
# Number of black pixels:  12561
# Area of black pixels in square millimeters:  34.92165619834711
# Number of black pixels:  12490
# Area of black pixels in square millimeters:  34.72426446280991
# Number of black pixels:  12443
# Area of black pixels in square millimeters:  34.593596694214874
# Number of black pixels:  12313
# Area of black pixels in square millimeters:  34.23217520661157
# Number of black pixels:  12286
# Area of black pixels in square millimeters:  34.15711074380165
# Number of black pixels:  12100
# Area of black pixels in square millimeters:  33.64
# Number of black pixels:  12051
# Area of black pixels in square millimeters:  33.50377190082644
# Number of black pixels:  12031
# Area of black pixels in square millimeters:  33.448168595041324
# Number of black pixels:  12191
# Area of black pixels in square millimeters:  33.892995041322315
# Number of black pixels:  12251
# Area of black pixels in square millimeters:  34.05980495867768
# Number of black pixels:  12301
# Area of black pixels in square millimeters:  34.1988132231405
# Number of black pixels:  12313
# Area of black pixels in square millimeters:  34.23217520661157
# Number of black pixels:  12410
# Area of black pixels in square millimeters:  34.50185123966942
# Number of black pixels:  12444
# Area of black pixels in square millimeters:  34.59637685950413
# Number of black pixels:  12488
# Area of black pixels in square millimeters:  34.7187041322314
# Number of black pixels:  12545
# Area of black pixels in square millimeters:  34.877173553719004
# Number of black pixels:  12573
# Area of black pixels in square millimeters:  34.95501818181818
# Number of black pixels:  12744
# Area of black pixels in square millimeters:  35.43042644628099
# Number of black pixels:  12865
# Area of black pixels in square millimeters:  35.76682644628099
# Number of black pixels:  12944
# Area of black pixels in square millimeters:  35.98645950413223
# Number of black pixels:  13020
# Area of black pixels in square millimeters:  36.197752066115704
# Number of black pixels:  13093
# Area of black pixels in square millimeters:  36.400704132231404
# Number of black pixels:  13060
# Area of black pixels in square millimeters:  36.30895867768595
# Number of black pixels:  13031
# Area of black pixels in square millimeters:  36.22833388429752
# Number of black pixels:  12931
# Area of black pixels in square millimeters:  35.9503173553719
# Number of black pixels:  12822
# Area of black pixels in square millimeters:  35.64727933884297
# Number of black pixels:  12704
# Area of black pixels in square millimeters:  35.319219834710744
# Number of black pixels:  12599
# Area of black pixels in square millimeters:  35.02730247933884
# Number of black pixels:  12536
# Area of black pixels in square millimeters:  34.8521520661157
# Number of black pixels:  12373
# Area of black pixels in square millimeters:  34.39898512396694
# Number of black pixels:  12328
# Area of black pixels in square millimeters:  34.27387768595041
# Number of black pixels:  12325
# Area of black pixels in square millimeters:  34.26553719008265
# Number of black pixels:  12237
# Area of black pixels in square millimeters:  34.020882644628095
# Number of black pixels:  12095
# Area of black pixels in square millimeters:  33.62609917355372
# Number of black pixels:  12000
# Area of black pixels in square millimeters:  33.36198347107438
# Number of black pixels:  11945
# Area of black pixels in square millimeters:  33.20907438016529
# Number of black pixels:  11939
# Area of black pixels in square millimeters:  33.19239338842975
# Number of black pixels:  11897
# Area of black pixels in square millimeters:  33.07562644628099
# Number of black pixels:  11835
# Area of black pixels in square millimeters:  32.90325619834711
# Number of black pixels:  11779
# Area of black pixels in square millimeters:  32.74756694214876
# Number of black pixels:  11794
# Area of black pixels in square millimeters:  32.7892694214876
# Number of black pixels:  11837
# Area of black pixels in square millimeters:  32.90881652892562
# Number of black pixels:  11900
# Area of black pixels in square millimeters:  33.083966942148756
# Number of black pixels:  11969
# Area of black pixels in square millimeters:  33.27579834710744
# Number of black pixels:  12031
# Area of black pixels in square millimeters:  33.448168595041324
# Number of black pixels:  12135
# Area of black pixels in square millimeters:  33.737305785123965
# Number of black pixels:  12181
# Area of black pixels in square millimeters:  33.86519338842975
# Number of black pixels:  12246
# Area of black pixels in square millimeters:  34.045904132231406
# Number of black pixels:  12284
# Area of black pixels in square millimeters:  34.15155041322314
# Number of black pixels:  12286
# Area of black pixels in square millimeters:  34.15711074380165
# Number of black pixels:  12335
# Area of black pixels in square millimeters:  34.2933388429752
# Number of black pixels:  12311
# Area of black pixels in square millimeters:  34.226614876033054
# Number of black pixels:  12287
# Area of black pixels in square millimeters:  34.159890909090905
# Number of black pixels:  12292
# Area of black pixels in square millimeters:  34.173791735537186
# Number of black pixels:  12388
# Area of black pixels in square millimeters:  34.44068760330578
# Number of black pixels:  12409
# Area of black pixels in square millimeters:  34.49907107438016
# Number of black pixels:  12558
# Area of black pixels in square millimeters:  34.91331570247934
# Number of black pixels:  12702
# Area of black pixels in square millimeters:  35.31365950413223
# Number of black pixels:  12699
# Area of black pixels in square millimeters:  35.30531900826446
# Number of black pixels:  12572
# Area of black pixels in square millimeters:  34.95223801652892
# Number of black pixels:  12506
# Area of black pixels in square millimeters:  34.76874710743802
# Number of black pixels:  12410
# Area of black pixels in square millimeters:  34.50185123966942
# Number of black pixels:  12246
# Area of black pixels in square millimeters:  34.045904132231406
# Number of black pixels:  12302
# Area of black pixels in square millimeters:  34.20159338842975
# Number of black pixels:  12349
# Area of black pixels in square millimeters:  34.33226115702479
# Number of black pixels:  12403
# Area of black pixels in square millimeters:  34.48239008264463
# Number of black pixels:  12599
# Area of black pixels in square millimeters:  35.02730247933884
# Number of black pixels:  12654
# Area of black pixels in square millimeters:  35.180211570247934
# Number of black pixels:  12642
# Area of black pixels in square millimeters:  35.14684958677686
# Number of black pixels:  12680
# Area of black pixels in square millimeters:  35.252495867768594
# Number of black pixels:  12692
# Area of black pixels in square millimeters:  35.28585785123967
# Number of black pixels:  12571
# Area of black pixels in square millimeters:  34.94945785123967
# Number of black pixels:  12582
# Area of black pixels in square millimeters:  34.98003966942149
# Number of black pixels:  12671
# Area of black pixels in square millimeters:  35.22747438016529
# Number of black pixels:  12784
# Area of black pixels in square millimeters:  35.541633057851236
# Number of black pixels:  12939
# Area of black pixels in square millimeters:  35.972558677685946
# Number of black pixels:  13056
# Area of black pixels in square millimeters:  36.29783801652892
# Number of black pixels:  13315
# Area of black pixels in square millimeters:  37.01790082644628
# Number of black pixels:  13575
# Area of black pixels in square millimeters:  37.74074380165289
# Number of black pixels:  14122
# Area of black pixels in square millimeters:  39.26149421487603
# Number of black pixels:  14479
# Area of black pixels in square millimeters:  40.2540132231405
# Number of black pixels:  14849
# Area of black pixels in square millimeters:  41.28267438016529
# Number of black pixels:  15227
# Area of black pixels in square millimeters:  42.33357685950413
# Number of black pixels:  15715
# Area of black pixels in square millimeters:  43.690297520661154
# Number of black pixels:  15896
# Area of black pixels in square millimeters:  44.193507438016525
# Number of black pixels:  15971
# Area of black pixels in square millimeters:  44.40201983471074
# Number of black pixels:  16007
# Area of black pixels in square millimeters:  44.502105785123966
# Number of black pixels:  16328
# Area of black pixels in square millimeters:  45.3945388429752
# Number of black pixels:  16644
# Area of black pixels in square millimeters:  46.27307107438016
# Number of black pixels:  16824
# Area of black pixels in square millimeters:  46.77350082644628
# Number of black pixels:  17003
# Area of black pixels in square millimeters:  47.27115041322314
# Number of black pixels:  17193
# Area of black pixels in square millimeters:  47.799381818181814
# Number of black pixels:  17383
# Area of black pixels in square millimeters:  48.327613223140496
# Number of black pixels:  17518
# Area of black pixels in square millimeters:  48.70293553719008
# Number of black pixels:  17547
# Area of black pixels in square millimeters:  48.78356033057851
# Number of black pixels:  17597
# Area of black pixels in square millimeters:  48.92256859504132
# Number of black pixels:  17741
# Area of black pixels in square millimeters:  49.322912396694214
# Number of black pixels:  17657
# Area of black pixels in square millimeters:  49.08937851239669
# Number of black pixels:  17801
# Area of black pixels in square millimeters:  49.48972231404959
# Number of black pixels:  17802
# Area of black pixels in square millimeters:  49.49250247933884
# Number of black pixels:  17748
# Area of black pixels in square millimeters:  49.34237355371901
# Number of black pixels:  17603
# Area of black pixels in square millimeters:  48.93924958677686
# Number of black pixels:  17447
# Area of black pixels in square millimeters:  48.50554380165289
# Number of black pixels:  17271
# Area of black pixels in square millimeters:  48.0162347107438
# Number of black pixels:  17140
# Area of black pixels in square millimeters:  47.652033057851234
# Number of black pixels:  16782
# Area of black pixels in square millimeters:  46.656733884297516
# Number of black pixels:  16476
# Area of black pixels in square millimeters:  45.80600330578512
# Number of black pixels:  16095
# Area of black pixels in square millimeters:  44.74676033057851
# Number of black pixels:  15775
# Area of black pixels in square millimeters:  43.85710743801653
# Number of black pixels:  15370
# Area of black pixels in square millimeters:  42.73114049586777
# Number of black pixels:  14982
# Area of black pixels in square millimeters:  41.65243636363636
# Number of black pixels:  14941
# Area of black pixels in square millimeters:  41.538449586776856
# Number of black pixels:  15076
# Area of black pixels in square millimeters:  41.91377190082645
# Number of black pixels:  15068
# Area of black pixels in square millimeters:  41.891530578512395
# Number of black pixels:  14952
# Area of black pixels in square millimeters:  41.56903140495868
# Number of black pixels:  15401
# Area of black pixels in square millimeters:  42.81732561983471
# Number of black pixels:  16403
# Area of black pixels in square millimeters:  45.60305123966942
# Number of black pixels:  16922
# Area of black pixels in square millimeters:  47.04595702479339
# Number of black pixels:  17084
# Area of black pixels in square millimeters:  47.49634380165289
# Number of black pixels:  16990
# Area of black pixels in square millimeters:  47.235008264462806
# Number of black pixels:  16431
# Area of black pixels in square millimeters:  45.68089586776859
# Number of black pixels:  15837
# Area of black pixels in square millimeters:  44.02947768595041
# Number of black pixels:  15108
# Area of black pixels in square millimeters:  42.00273719008264
# Number of black pixels:  15189
# Area of black pixels in square millimeters:  42.22793057851239
# Number of black pixels:  15199
# Area of black pixels in square millimeters:  42.255732231404956
# Number of black pixels:  15136
# Area of black pixels in square millimeters:  42.08058181818182
# Number of black pixels:  15270
# Area of black pixels in square millimeters:  42.453123966942144
# Number of black pixels:  15254
# Area of black pixels in square millimeters:  42.40864132231405
# Number of black pixels:  15413
# Area of black pixels in square millimeters:  42.850687603305786
# Number of black pixels:  15614
# Area of black pixels in square millimeters:  43.409500826446276
# Number of black pixels:  15802
# Area of black pixels in square millimeters:  43.93217190082645
# Number of black pixels:  15950
# Area of black pixels in square millimeters:  44.343636363636364
# Number of black pixels:  16062
# Area of black pixels in square millimeters:  44.65501487603306
# Number of black pixels:  16025
# Area of black pixels in square millimeters:  44.552148760330574
# Number of black pixels:  15904
# Area of black pixels in square millimeters:  44.21574876033058
# Number of black pixels:  15644
# Area of black pixels in square millimeters:  43.492905785123966
# Number of black pixels:  15355
# Area of black pixels in square millimeters:  42.689438016528925
# Number of black pixels:  14940
# Area of black pixels in square millimeters:  41.535669421487604
# Number of black pixels:  14688
# Area of black pixels in square millimeters:  40.83506776859504
# Number of black pixels:  14099
# Area of black pixels in square millimeters:  39.19755041322314
# Number of black pixels:  13068
# Area of black pixels in square millimeters:  36.331199999999995
# Number of black pixels:  12368
# Area of black pixels in square millimeters:  34.38508429752066
# Number of black pixels:  11789
# Area of black pixels in square millimeters:  32.77536859504132
# Number of black pixels:  11163
# Area of black pixels in square millimeters:  31.03498512396694
# Number of black pixels:  10463
# Area of black pixels in square millimeters:  29.0888694214876
# Number of black pixels:  10158
# Area of black pixels in square millimeters:  28.240919008264463
# Number of black pixels:  9062
# Area of black pixels in square millimeters:  25.193857851239667
# Number of black pixels:  7832
# Area of black pixels in square millimeters:  21.774254545454543
# Number of black pixels:  7013
# Area of black pixels in square millimeters:  19.497299173553717
# Number of black pixels:  6297
# Area of black pixels in square millimeters:  17.50670082644628
# Number of black pixels:  6573
# Area of black pixels in square millimeters:  18.274026446280992
# Number of black pixels:  5697
# Area of black pixels in square millimeters:  15.838601652892562
# Number of black pixels:  5321
# Area of black pixels in square millimeters:  14.79325950413223
# Number of black pixels:  4336
# Area of black pixels in square millimeters:  12.054796694214875
# Number of black pixels:  4194
# Area of black pixels in square millimeters:  11.660013223140496
# Number of black pixels:  3808
# Area of black pixels in square millimeters:  10.586869421487602
# Number of black pixels:  2964
# Area of black pixels in square millimeters:  8.240409917355372
# Number of black pixels:  2507
# Area of black pixels in square millimeters:  6.969874380165289
# Number of black pixels:  2192
# Area of black pixels in square millimeters:  6.094122314049587
# Number of black pixels:  2258
# Area of black pixels in square millimeters:  6.277613223140496
