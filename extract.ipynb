# %%
import cv2
import os
from matplotlib import pyplot as plt
import numpy as np
# Define the paths to the cropped image folders
cropped_p1_folder = './cropped_binary_resized_mirror/cropped_binary_resized_mirror_p1/'
cropped_p2_folder = './cropped_binary_resized_mirror/cropped_binary_resized_mirror_p2/'

# Create a folder to save the extracted images
extracted_folder = './p2-7_extracted_cropped_binary/p2_extracted/'
if not os.path.exists(extracted_folder):
    os.makedirs(extracted_folder)

# Get the list of files in cropped_p2 folder
files_p2 = os.listdir(cropped_p2_folder)

# Iterate over the files in cropped_p2 folder
for file_p2 in files_p2:
    # Construct the paths for the corresponding images in cropped_p1 and cropped_p2 folders
    file_p1 = os.path.join(cropped_p1_folder, 'p1_0001.bmp')
    file_p2 = os.path.join(cropped_p2_folder, file_p2)
    
    # Read the images
    img_p1 = cv2.imread(file_p1, cv2.IMREAD_GRAYSCALE)
    img_p2 = cv2.imread(file_p2, cv2.IMREAD_GRAYSCALE)
    

    # plt.imshow(img_p2, cmap='gray')
    # plt.axis('on')  # Turn off axis numbers
    # plt.show()
    # Subtract the images
    extracted_image = cv2.subtract(img_p1, img_p2)


    contours, _ = cv2.findContours(extracted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate over contours
    for contour in contours:
        area = cv2.contourArea(contour)
        if area < 1000:
            cv2.drawContours(extracted_image, [contour], -1, 0, thickness=cv2.FILLED)


    white_pixel_threshold = 5
    for col in range(extracted_image.shape[1]):
        white_pixel_count = np.sum(extracted_image[:, col] == 255)
        if white_pixel_count <= white_pixel_threshold:
            extracted_image[:, col] = 0  # Convert the column to black pixels

    extracted_image = cv2.bitwise_not(extracted_image)

    black_pixel_count = np.sum(extracted_image == 0)
    print("Number of black pixels: ", black_pixel_count)
    # Calculate the area of black pixels in square millimeters
    black_area_mm = black_pixel_count * (29/547)**2
    print("Area of black pixels in square millimeters: ", black_area_mm)
    
    plt.imshow(extracted_image, cmap='gray')
    plt.axis('on')  # Turn off axis numbers
    plt.show()
    # Save the extracted image
    file_p2 = file_p2.replace('p2_','')
    # cv2.imwrite(os.path.join(extracted_folder, 'p2_extracted_' + file_p2.split("/")[-1]).replace('p2_',''), extracted_image)
    cv2.imwrite(os.path.join(extracted_folder, 'p2_extracted_' + file_p2.split("/")[-1]), extracted_image)
# Out:
# Number of black pixels:  14795
# Area of black pixels in square millimeters:  41.58496235073142
# Number of black pixels:  14821
# Area of black pixels in square millimeters:  41.658041703291005
# Number of black pixels:  14810
# Area of black pixels in square millimeters:  41.627123515669645
# Number of black pixels:  14765
# Area of black pixels in square millimeters:  41.50064002085499
# Number of black pixels:  14718
# Area of black pixels in square millimeters:  41.368535037381896
# Number of black pixels:  14675
# Area of black pixels in square millimeters:  41.24767303122566
# Number of black pixels:  14670
# Area of black pixels in square millimeters:  41.23361930957959
# Number of black pixels:  14723
# Area of black pixels in square millimeters:  41.38258875902797
# Number of black pixels:  14806
# Area of black pixels in square millimeters:  41.61588053835279
# Number of black pixels:  15041
# Area of black pixels in square millimeters:  42.27640545571824
# ...
