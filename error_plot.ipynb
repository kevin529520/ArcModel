# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from error.txt
data = pd.read_csv('error.txt', header=None)

# Extracting data for x, y, and radius errors
plt.hist(data[0], bins=40, color='blue', alpha=0.7, label='X Error')
plt.legend()
plt.show()
# plt.hist(data[1], bins=20, color='orange', alpha=0.7, label='Y Error')
# plt.legend()
# plt.show()
# radius_error = data[2]
# plt.plot(radius_error, label='r Error')
# # Plotting the errors
# plt.figure(figsize=(12, 6))
# # print(x_error)
# plt.plot(x_error, label='X Error')
# plt.plot(y_error, label='Y Error')
# plt.plot(radius_error, label='Radius Error')
# plt.xlabel('Data Point')
# plt.ylabel('Error')
# plt.title('Error Analysis of Circle Fitting')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.rc('font',family='Times New Roman')

plt.rcParams.update({'font.size': 12})

# Load the data from error.txt
data = pd.read_csv('error.txt', header=None)
print(type(data[1]))
num_bins = 80

fig, ax = plt.subplots(figsize=(4.13, 3), dpi=300)

# the histogram of the data
n, bins, patches = ax.hist(data[0], num_bins, density=True)
# sns.kdeplot(data[0], color='orange', label='Density Curve', linestyle='--')
# plt.show()
# plt.legend()

# ax.plot(bins, y, '--')
ax.set_xlabel('Fitting error (pixel)')
ax.set_ylabel('Probability density')
# ax.set_title('Histogram of fitting error distribution ')
# ax.set_title('Histogram of fitting error distribution for dataset')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data from error.txt
data = pd.read_csv('error.txt', header=None)
print(type(data[1]))
num_bins = 80

fig, ax = plt.subplots(figsize=(4.13, 3), dpi=300)

# the histogram of the data
n, bins, patches = ax.hist(data[1], num_bins, density=True, color = 'green')
# sns.kdeplot(data[1], color='orange', label='Density Curve', linestyle='--')
# plt.show()


# ax.plot(bins, y, '--')
ax.set_xlabel('Coefficient of determination (R$^2$)')
ax.set_ylabel('Probability density')
# ax.set_title('Histogram of coefficient of determination(R$^2$) distribution ')
# plt.legend()

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import pygwalker as pyg

# %%
df = pd.read_csv('try.txt')
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-00061702148b211e26owHqXxCEkbQlsg" style="height: auto">\n    <head>…

# %%
import matplotlib.pyplot as plt
import seaborn as sns
 
# 导入数据集
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
